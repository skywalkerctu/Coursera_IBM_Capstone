# %% [markdown]
# # <center>How to choose a location for a new coffee shop in Taipei</center>

# %% [markdown]
# ### <center>2019/05/05</center>
#
# <center>By Hanniel, Shih</center>

# %% [markdown]
# # Introduction

# %% [markdown]
# ## Background

# %% [markdown]
# In Taipei, there are a lot of coffee shops, but not all are running well. <br>
#
# There are a lot of factors to consider when planning to open a new coffee shop, but for this project, we will focus on the location of it.
#
# The location for a coffee shop is closely related to their business, especially in Taipei, as the majority of people in Taipei rely on public transportation to move around the city.<br>

# %% [markdown]
# ## Business problem

# %% [markdown]
# What is the best location for a coffee shop to be?
#
# What type of venues nearby should one look for or avoid?

# %% [markdown]
# ## Target of this report

# %% [markdown]
# People who wants to open a coffee shop in Taipei, but has not decided the location.

# %% [markdown]
# # Data

# %% [markdown]
# In this project, we will be using primarily the foursquare location dataset.<br>
# Below is an example of the data that we will use.

# %%
# @hidden_cell
CLIENT_ID = 'TFBQ3TCNGGG12CQDSF0LJSXUVGADSDLUEVEDRXEUW0P21W0F' # your Foursquare ID
CLIENT_SECRET = '4AJRYELS00FWGQFH20DYLZ4VV2NGHK3JFZZUFS13A1IAKB0R' # your Foursquare Secret
VERSION = '20180628' # Foursquare API version

# %%
import json, requests, pandas as pd
url = 'https://api.foursquare.com/v2/venues/explore'

params = dict(
  client_id=CLIENT_ID,
  client_secret=CLIENT_SECRET,
  v=VERSION,
  ll='25.0833,121.517',
  query='coffee',
  limit=5
)
resp = requests.get(url=url, params=params)
data = json.loads(resp.text)
#print(data)
results=data['response']['groups'][0]['items']
ids=[]
for i in results:
    #print(i['venue']['id'])
    ids.append(i['venue']['id'])

# %%
info=[]
for VENUE_ID in ids:
    #VENUE_ID='52fefe3f11d2a6f087c20989'
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
        VENUE_ID,        
        CLIENT_ID, 
                CLIENT_SECRET, 
                VERSION
    )
    results = requests.get(url).json()['response']['venue']
    #print(results)
    info.append([results['name'],results['likes']['count'],results['rating'],results['location']['lat'],results['location']['lng']])
df=pd.DataFrame(info)
df.columns=['Name','Likes','rating','latitude','longitude']
#print(results)
df
# Out:
#                                       Name  Likes  ...   latitude   longitude
# 0                         咖啡弄 Coffee Alley     14  ...  25.088665  121.526480
# 1  STARBUCKS (Kulun Chengde) (星巴克（庫倫承德門市）)     20  ...  25.072044  121.518828
# 2                           松鶴廳 Lobby Cafe      8  ...  25.078453  121.526220
# 3                         榕 RON Cafe + Bar     24  ...  25.091518  121.526787
# 4                            星巴克 Starbucks      4  ...  25.081778  121.523048
#
# [5 rows x 5 columns]

# %% [markdown]
# # Methodology

# %% [markdown]
# Let's create a function that returns coffee shops near a given location.

# %%
def get_coffees(lal,num):
    import json, requests, pandas as pd,numpy as np
    url = 'https://api.foursquare.com/v2/venues/explore'

    params = dict(
      client_id=CLIENT_ID,
      client_secret=CLIENT_SECRET,
      v=VERSION,
      ll=lal,
      query='coffee',
      limit=num
    )
    resp = requests.get(url=url, params=params)
    data = json.loads(resp.text)
    #print(data)
    results=data['response']['groups'][0]['items']
    ids=[]
    for i in results:
        #print(i['venue']['id'])
        ids.append(i['venue']['id'])
    info=[]
    for VENUE_ID in ids:
        #VENUE_ID='52fefe3f11d2a6f087c20989'
        url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            VENUE_ID,        
            CLIENT_ID, 
                    CLIENT_SECRET, 
                    VERSION
        )
        while True:
            results = requests.get(url)
            if results.status_code == requests.codes.ok:
                break
        #print(results)
        results=results.json()['response']['venue']
        try:
            rating=results['rating']
        except:
            rating=np.nan
        info.append([results['name'],results['likes']['count'],rating,results['location']['lat'],results['location']['lng']])
    df=pd.DataFrame(info)
    df.columns=['Name','Likes','rating','latitude','longitude']
    #print(results)
    return df

# %% [markdown]
# Due to the limit of only 500 calls allowed per day with foursquare API, it's not possible to get the data of every coffee shop in Taipei.
#
# Instead, we will first choose two districts in Taipei with the best overall score.
#
# Get 10 coffee shops in every district

# %%
df_Shilin=get_coffees('25.0833,121.517',10)

# %%
df_Beitou=get_coffees('25.1167,121.5',10)

# %%
df_Neihu=get_coffees('25.04,121.35',10)

# %%
df_Wenshan=get_coffees('24.989722,121.572222',10)

# %%
df_Nangang=get_coffees('25.053315,121.607409',10)

# %%
df_Zhongshan=get_coffees('25.068889,121.533056',10)

# %%
df_Daan=get_coffees('25.026389,121.534444',10)

# %%
df_Xinyi=get_coffees('25.035833,121.568333',10)

# %%
df_Songshan=get_coffees('25.059788,121.55727',10)

# %%
df_Wanhua=get_coffees('25.0333,121.483',10)

# %%
df_Zhongzheng=get_coffees('25.031667,121.516389',10)

# %%
df_Datong=get_coffees('25.059722,121.514167',10)

# %% [markdown]
# Calculate score for each district.
#
# The score here is defined to be (number of likes)+10*(rating)

# %%
score=[]
for i in [df_Shilin,df_Beitou,df_Neihu,df_Wenshan,df_Nangang,df_Zhongshan,df_Daan,df_Xinyi,df_Songshan,df_Wanhua,df_Zhongzheng,df_Datong]:
    score.append(i.describe().loc['mean']['Likes']+10*i.describe().loc['mean']['rating'])
for s in score:
    print(s)
# Out:
# 82.2
# 87.29999999999998
# 74.67777777777778
# 88.1
# 75.77777777777777
# 76.3
# 114.7
# 103.0
# 118.9
# 82.6
# 97.9
# 102.49999999999999

# %% [markdown]
# Songshan District has the best overall customer statisfation, followed by Da'an District.<br>
# We will use coffee shops in these two districts to answer our question.

# %% [markdown]
# (Coffee shops with no rating is filled with the average rating in that district.)

# %% [markdown]
# ### Songshan District

# %%
df=get_coffees('25.059788,121.55727',200)

# %%
df['score']=df['Likes']+10*df['rating'].fillna(df['rating'].mean())
df
# Out:
#                                                Name  ...       score
# 0               Fujin Tree 353 Cafe by Simple Kaffa  ...  149.000000
# 1                          All Day Roasting Company  ...  160.000000
# 2                           Coffee Essential (民生工寓)  ...  164.000000
# 3                                 左先生咖啡 Dousun Cafe  ...  110.000000
# 4                                              楽楽咖啡  ...  129.000000
# 5                         STARBUCKS (San Min) (星巴克)  ...  100.000000
# 6                                     Woolloomooloo  ...  122.000000
# 7                                           六丁目cafe  ...   91.000000
# 8                                      Leisure Cafe  ...   89.000000
# 9                                     朋廚烘培坊 Bonjour  ...   75.000000
# 10                                    小春日和 動物雜貨• 珈琲  ...   74.000000
# 11                    Wilbeck Café (威爾貝克手工烘咖啡（南京店）)  ...   85.000000
# 12                                          春水堂 光南店  ...   99.000000
# 13                                  小草 作 Grassphere  ...   70.000000
# 14                                    BEANS & BEATS  ...   67.000000
# 15                         Kyushu Pancake (九州鬆餅咖啡店)  ...   76.000000
# 16                                   Café Mode (木馬)  ...   64.000000
# 17                                            De 'A  ...   65.000000
# 18                                  Starbucks (星巴克)  ...   73.000000
# 19                                芭蕾咖啡館 Cafe Ballet  ...   65.000000
# 20                                         J12 Cafe  ...   63.000000
# 21                                            Pausa  ...   69.521739
# 22                                       Polar Cafe  ...   70.521739
# 23                                        3,CO Cafe  ...   71.521739
# 24                         Cafe Ballet-Baby Kitchen  ...   70.521739
# 25                                     Mister Donut  ...   69.521739
# 26                                     Cafe Coabana  ...   74.521739
# 27                     Milkglider Latteartist Unity  ...   67.000000
# 28                                       cafe apron  ...   71.521739
# 29                                            晴空巷咖啡  ...   72.521739
# 30                                               琅茶  ...   75.521739
# 31                                           小樽手作咖啡  ...   74.521739
# 32                                天仁茗茶 TenRen's Tea  ...   69.521739
# 33                         松果院子 Restaurant Pinecone  ...   74.521739
# 34            Quote Select Shop / Coffee & Sundries  ...   72.521739
# 35                                    Cafe Showroom  ...   72.521739
# 36                                       Red Circle  ...   69.521739
# 37                                  Afterhours Café  ...   75.000000
# 38                              Louisa Coffee 民生富錦店  ...   70.521739
# 39                                               覓熊  ...   71.521739
# 40                                          阿力的搖滾廚房  ...   71.521739
# 41                                丹堤咖啡 Dante Coffee  ...   70.521739
# 42                                丹堤咖啡 Dante Coffee  ...   69.521739
# 43                                  敝所咖啡 Bison Cafe  ...   73.521739
# 44                                            亞熱帶餐廳  ...   69.521739
# 45                                              三佰斤  ...   69.521739
# 46                           伯朗咖啡館 Mr. Brown Coffee  ...   72.521739
# 47             Peloso Coffee Roasters 2 (沛洛瑟珈琲店．之二)  ...   73.521739
# 48  Mr. Brown Coffee Taipei Airport 2 (伯朗咖啡 松山機場二店)  ...   71.521739
# 49                                    A. Place Cafe  ...   71.521739
# 50                              Louisa coffee 民生圓環店  ...   74.521739
# 51                                          清玉手調原味茶  ...   69.521739
#
# [52 rows x 6 columns]

# %% [markdown]
# ### Da'an District

# %%
df_1=get_coffees('25.026389,121.534444',200)

# %%
df_1['score']=df_1['Likes']+10*df_1['rating'].fillna(df_1['rating'].mean())
df_1
# Out:
#                                     Name  Likes  ...   longitude       score
# 0                                   青田七六     46  ...  121.532596  129.000000
# 1               Wistaria Tea House (紫藤廬)     70  ...  121.534507  150.000000
# 2                                   貳月咖啡     10  ...  121.532101   91.000000
# 3                       515 cafe & books      8  ...  121.531372   88.000000
# 4                     咖啡黑潮 Cafe Kuroshio     22  ...  121.530545  100.000000
# 5                                2J Cafe     16  ...  121.538382  101.000000
# 6                         葛樂蒂咖啡館 Galette      8  ...  121.533913   86.000000
# 7                         AGCT Apartment     14  ...  121.533101   95.000000
# 8                      Yaboo Cafe (鴉埠咖啡)     73  ...  121.530520  155.000000
# 9            Libero Coffee & Bar (咖啡小自由)     73  ...  121.530538  152.000000
# 10                             Take Five     25  ...  121.530574  100.000000
# 11                     Ecole Cafe (學校咖啡)     31  ...  121.532174  104.000000
# 12                                  青田茶館      9  ...  121.530831   82.000000
# 13                   喜鵲咖啡 Pica Pica Café     23  ...  121.531835  101.000000
# 14                       誰的書房 who's café     13  ...  121.530792   87.000000
# 15                         Flügel Studio     34  ...  121.530162  115.000000
# 16                               Hi (日楞)     67  ...  121.526758  148.000000
# 17                   永康階 The Green Steps     25  ...  121.530116  101.000000
# 18                         MuNiau (沐肆貓廬)      7  ...  121.527618   84.000000
# 19                     Le Chat (路上撿到一隻貓)     45  ...  121.533092  118.000000
# 20                     Xiaomijo (小米酒咖啡館)     23  ...  121.529595   98.000000
# 21               串門子茶館 Stop By Tea House     12  ...  121.529303   86.000000
# 22                                  靈感咖啡      7  ...  121.533560   84.000000
# 23    天下佈武 日月潭紅茶 Sun Moon Lake Black Tea     30  ...  121.528230  103.000000
# 24      自然醒咖啡公寓 Wakin' Up Cafe Apartment     15  ...  121.541080   88.000000
# 25                     小慢 Tea Experience     10  ...  121.529393   80.000000
# 26                        petit doux 微小甜     11  ...  121.530573   85.000000
# 27  Youmou to Ohana Coffee (羊毛與花 coffee)     10  ...  121.529933   81.000000
# 28             Rebirth Cafe & Restaurant      7  ...  121.533073   77.000000
# 29           烘培者咖啡 Roaster Family Coffee     20  ...  121.530360   90.000000
# ..                                   ...    ...  ...         ...         ...
# 55                    極簡咖啡館 Minimal Café     27  ...  121.529556   87.000000
# 56                 滴咖啡 Drop Coffee House      8  ...  121.533600   70.000000
# 57                   Good Studio (好氏研究室)     15  ...  121.531842   75.000000
# 58                      Okey Dockey Cafe      5  ...  121.533099   66.000000
# 59                        Café à la Mode      8  ...  121.527038   68.000000
# 60                  路易 莎咖啡 Louisa Coffee      4  ...  121.538537   74.903226
# 61    BackStage Cafe (後台 BackStage Cafe)      1  ...  121.534810   71.903226
# 62                    Café Trouvé (找到咖啡)      3  ...  121.534009   61.000000
# 63                        Cafe Fudgetori      3  ...  121.528545   73.903226
# 64                                  聞山咖啡      6  ...  121.533680   76.903226
# 65                                 小木屋鬆餅      2  ...  121.528593   72.903226
# 66                                   天曉得      2  ...  121.528969   72.903226
# 67                     小南風 Minami Zephyr      0  ...  121.527948   70.903226
# 68                                  米倉咖啡      2  ...  121.529237   72.903226
# 69                   Rose House 古典玫瑰園師大店      1  ...  121.528645   71.903226
# 70               Film Studio Café (片場咖啡)      2  ...  121.533195   72.903226
# 71                         朱利安諾 Giuliano      1  ...  121.532649   71.903226
# 72                  路易．莎咖啡 Louisa Coffee      1  ...  121.528292   71.903226
# 73                       斑比咖啡 Bambi Cafe      1  ...  121.526934   71.903226
# 74                       路燈咖啡 Light Cafe      9  ...  121.526904   64.000000
# 75                  Jamaica Cafe (牙買加倉庫)      0  ...  121.537914   70.903226
# 76                             コーヒー山田珈琲店      6  ...  121.531432   76.903226
# 77                               50嵐 師大店      2  ...  121.528380   72.903226
# 78                  Guang Yi Cafe (光一肆號)      1  ...  121.533605   71.903226
# 79       Piglet Friendly Café (彼克蕾友善咖啡館)      3  ...  121.533459   73.903226
# 80                              一芳 台灣水果茶      1  ...  121.528040   71.903226
# 81             真書軒 The Jen Library (真書軒)      5  ...  121.536379   75.903226
# 82                       Good Goods Cafe      1  ...  121.534464   71.903226
# 83                     丹堤咖啡 Dante Coffee      0  ...  121.541034   70.903226
# 84                   魯米爺咖啡館 Café Lumiere      1  ...  121.532838   71.903226
#
# [85 rows x 6 columns]

# %% [markdown]
# Now, let's explore the area of each coffee shops.
#
# Here we create a function that returns every venue in a radius of 200 meters

# %%
def explore_area(lat,lon):
    import json, requests, pandas as pd,numpy as np
    url = 'https://api.foursquare.com/v2/venues/search'

    params = dict(
      client_id=CLIENT_ID,
      client_secret=CLIENT_SECRET,
      v=VERSION,
      ll=str(lat)+','+str(lon),
      radius=200,
      intent='browse'
    )
    while True:
        resp = requests.get(url=url, params=params)
        if resp.status_code == requests.codes.ok:
            break
    data = json.loads(resp.text)
    #print(data)
    venues_list=data['response']['venues']
    cat_list=[]
    id_list=[]
    for venue in venues_list:
        if venue['location']['distance']!=0 and venue['categories']!=[]:
            cat_list.append(venue['categories'][0]['name'])
            #id_list.append(venue['id'])
        #except:
         #   pass
    temp_df=pd.DataFrame(data={'category':cat_list})
    #temp_df.columns=['name','category']
    #temp_df=temp_df.groupby('category')['frequency'].nunique().to_frame().reset_index()
    #temp_df.insert(0,'Name',name)
    return temp_df

# %% [markdown]
# ### Songshan District

# %%
df_nearby=pd.DataFrame(columns=['Name','category'])
#df_nearby.columns=['Name','category','frequency']
for name,lat,lon in zip(df['Name'],df['latitude'],df['longitude']):
    df_temp=explore_area(lat,lon)
    df_temp.insert(0,'Name',name)
    df_nearby=df_nearby.append(df_temp,ignore_index=True,sort=False)
    #print(explore_area(name,lat,lon))
df_nearby
# Out:
#                                      Name                                  category
# 0     Fujin Tree 353 Cafe by Simple Kaffa                            Clothing Store
# 1     Fujin Tree 353 Cafe by Simple Kaffa                                      Park
# 2     Fujin Tree 353 Cafe by Simple Kaffa                                Baby Store
# 3     Fujin Tree 353 Cafe by Simple Kaffa                            Breakfast Spot
# 4     Fujin Tree 353 Cafe by Simple Kaffa                                      Café
# 5     Fujin Tree 353 Cafe by Simple Kaffa                           Nature Preserve
# 6     Fujin Tree 353 Cafe by Simple Kaffa                    Furniture / Home Store
# 7     Fujin Tree 353 Cafe by Simple Kaffa                                Kids Store
# 8     Fujin Tree 353 Cafe by Simple Kaffa                                      Park
# 9     Fujin Tree 353 Cafe by Simple Kaffa                                      Café
# 10    Fujin Tree 353 Cafe by Simple Kaffa                       Dumpling Restaurant
# 11    Fujin Tree 353 Cafe by Simple Kaffa                                      Café
# 12    Fujin Tree 353 Cafe by Simple Kaffa                       Japanese Restaurant
# 13    Fujin Tree 353 Cafe by Simple Kaffa                                Sports Bar
# 14    Fujin Tree 353 Cafe by Simple Kaffa                                      Café
# 15    Fujin Tree 353 Cafe by Simple Kaffa                      Taiwanese Restaurant
# 16    Fujin Tree 353 Cafe by Simple Kaffa                            Animal Shelter
# 17    Fujin Tree 353 Cafe by Simple Kaffa                                    Office
# 18    Fujin Tree 353 Cafe by Simple Kaffa                                    Office
# 19    Fujin Tree 353 Cafe by Simple Kaffa                                    Arcade
# 20    Fujin Tree 353 Cafe by Simple Kaffa                                 Juice Bar
# 21    Fujin Tree 353 Cafe by Simple Kaffa                              Noodle House
# 22               All Day Roasting Company                                Restaurant
# 23               All Day Roasting Company                           Doctor's Office
# 24               All Day Roasting Company                         Convenience Store
# 25               All Day Roasting Company                               Beer Garden
# 26               All Day Roasting Company  Residential Building (Apartment / Condo)
# 27               All Day Roasting Company                                Food Stand
# 28               All Day Roasting Company                          Community Center
# 29               All Day Roasting Company                         French Restaurant
# ...                                   ...                                       ...
# 1391                  Louisa coffee 民生圓環店                         Food & Drink Shop
# 1392                  Louisa coffee 民生圓環店                            Breakfast Spot
# 1393                  Louisa coffee 民生圓環店                            Breakfast Spot
# 1394                              清玉手調原味茶                        Chinese Restaurant
# 1395                              清玉手調原味茶                      Taiwanese Restaurant
# 1396                              清玉手調原味茶                      Hong Kong Restaurant
# 1397                              清玉手調原味茶                                Steakhouse
# 1398                              清玉手調原味茶                              Neighborhood
# 1399                              清玉手調原味茶                       Japanese Restaurant
# 1400                              清玉手調原味茶                          Asian Restaurant
# 1401                              清玉手調原味茶                   Chinese Breakfast Place
# 1402                              清玉手調原味茶                         Food & Drink Shop
# 1403                              清玉手調原味茶                                 Locksmith
# 1404                              清玉手調原味茶                         Electronics Store
# 1405                              清玉手調原味茶                              Dessert Shop
# 1406                              清玉手調原味茶                      Taiwanese Restaurant
# 1407                              清玉手調原味茶                       Japanese Restaurant
# 1408                              清玉手調原味茶                      Taiwanese Restaurant
# 1409                              清玉手調原味茶                            Breakfast Spot
# 1410                              清玉手調原味茶                         Convenience Store
# 1411                              清玉手調原味茶                       Japanese Restaurant
# 1412                              清玉手調原味茶                               Medical Lab
# 1413                              清玉手調原味茶                          Dentist's Office
# 1414                              清玉手調原味茶                             Grocery Store
# 1415                              清玉手調原味茶                       Japanese Restaurant
# 1416                              清玉手調原味茶                                  Bus Stop
# 1417                              清玉手調原味茶                         Convenience Store
# 1418                              清玉手調原味茶                      Fast Food Restaurant
# 1419                              清玉手調原味茶                             Middle School
# 1420                              清玉手調原味茶                              Noodle House
#
# [1421 rows x 2 columns]

# %% [markdown]
# ### Da'an District

# %%
df_1_nearby=pd.DataFrame(columns=['Name','category'])
#df_nearby.columns=['Name','category','frequency']
for name,lat,lon in zip(df_1['Name'],df_1['latitude'],df_1['longitude']):
    df_temp=explore_area(lat,lon)
    df_temp.insert(0,'Name',name)
    df_1_nearby=df_1_nearby.append(df_temp,ignore_index=True,sort=False)
    #print(explore_area(name,lat,lon))
df_1_nearby
# Out:
#                           Name                      category
# 0                         青田七六                          Park
# 1                         青田七六                        Bistro
# 2                         青田七六                 Historic Site
# 3                         青田七六              Confucian Temple
# 4                         青田七六                Used Bookstore
# 5                         青田七六                        Church
# 6                         青田七六                   Art Gallery
# 7                         青田七六                        Mosque
# 8                         青田七六                  Camera Store
# 9                         青田七六                      Tea Room
# 10                        青田七六                   Art Gallery
# 11                        青田七六              Asian Restaurant
# 12                        青田七六              Dentist's Office
# 13                        青田七六                      Tea Room
# 14                        青田七六                      Tea Room
# 15                        青田七六         Indonesian Restaurant
# 16                        青田七六                        Mosque
# 17                        青田七六                  Burger Joint
# 18                        青田七六                   Tailor Shop
# 19                        青田七六                  Dessert Shop
# 20                        青田七六                        Church
# 21                        青田七六                          Café
# 22                        青田七六            Athletics & Sports
# 23                        青田七六                    Restaurant
# 24                        青田七六            Salon / Barbershop
# 25                        青田七六                          Café
# 26                        青田七六                          Café
# 27    Wistaria Tea House (紫藤廬)                   Art Gallery
# 28    Wistaria Tea House (紫藤廬)  General College & University
# 29    Wistaria Tea House (紫藤廬)                   Bus Station
# ...                        ...                           ...
# 2326         丹堤咖啡 Dante Coffee            Chinese Restaurant
# 2327         丹堤咖啡 Dante Coffee             College Classroom
# 2328       魯米爺咖啡館 Café Lumiere                Breakfast Spot
# 2329       魯米爺咖啡館 Café Lumiere                          Café
# 2330       魯米爺咖啡館 Café Lumiere                          Café
# 2331       魯米爺咖啡館 Café Lumiere                Breakfast Spot
# 2332       魯米爺咖啡館 Café Lumiere      College Basketball Court
# 2333       魯米爺咖啡館 Café Lumiere                   Bus Station
# 2334       魯米爺咖啡館 Café Lumiere                   Pizza Place
# 2335       魯米爺咖啡館 Café Lumiere                           Bar
# 2336       魯米爺咖啡館 Café Lumiere                          Café
# 2337       魯米爺咖啡館 Café Lumiere                  Dessert Shop
# 2338       魯米爺咖啡館 Café Lumiere            Italian Restaurant
# 2339       魯米爺咖啡館 Café Lumiere                        Church
# 2340       魯米爺咖啡館 Café Lumiere       Health & Beauty Service
# 2341       魯米爺咖啡館 Café Lumiere             Korean Restaurant
# 2342       魯米爺咖啡館 Café Lumiere                Clothing Store
# 2343       魯米爺咖啡館 Café Lumiere                          Café
# 2344       魯米爺咖啡館 Café Lumiere                     Bookstore
# 2345       魯米爺咖啡館 Café Lumiere                Ice Cream Shop
# 2346       魯米爺咖啡館 Café Lumiere            Chinese Restaurant
# 2347       魯米爺咖啡館 Café Lumiere                          Tree
# 2348       魯米爺咖啡館 Café Lumiere           Szechuan Restaurant
# 2349       魯米爺咖啡館 Café Lumiere           Leather Goods Store
# 2350       魯米爺咖啡館 Café Lumiere                Ice Cream Shop
# 2351       魯米爺咖啡館 Café Lumiere             Hotpot Restaurant
# 2352       魯米爺咖啡館 Café Lumiere          Fast Food Restaurant
# 2353       魯米爺咖啡館 Café Lumiere                  Noodle House
# 2354       魯米爺咖啡館 Café Lumiere                        Church
# 2355       魯米爺咖啡館 Café Lumiere                  Dessert Shop
#
# [2356 rows x 2 columns]

# %% [markdown]
# Merge the 2 dataframes above and convert them into an one hot encoded table of categories of nearby venues.

# %%
df_around=df_nearby.append(df_1_nearby)
df_around_oh=pd.get_dummies(df_around[['category']],prefix='',prefix_sep='')
df_around_oh.insert(0,'Name',df_around['Name'])
df_grouped=df_around_oh.groupby('Name').sum().reset_index()
df_grouped
# Out:
#                                     Name  ...  Yoga Studio
# 0                                2J Cafe  ...            0
# 1                              3,CO Cafe  ...            1
# 2                                50嵐 師大店  ...            0
# 3                       515 cafe & books  ...            0
# 4                          A. Place Cafe  ...            0
# 5                         AGCT Apartment  ...            0
# 6                        Afterhours Café  ...            0
# 7               All Day Roasting Company  ...            0
# 8        Angle Café (Angle cafe 自家烘焙咖啡館)  ...            0
# 9                          BEANS & BEATS  ...            0
# 10    BackStage Cafe (後台 BackStage Cafe)  ...            0
# 11              Cafe Ballet-Baby Kitchen  ...            0
# 12                         Cafe Bastille  ...            0
# 13                          Cafe Coabana  ...            0
# 14                        Cafe Fudgetori  ...            0
# 15                            Cafe Odeon  ...            0
# 16                         Cafe Showroom  ...            0
# 17                         Café Bastille  ...            0
# 18                        Café Mode (木馬)  ...            1
# 19                    Café Trouvé (找到咖啡)  ...            0
# 20                        Café à la Mode  ...            0
# 21                          Cama 現烘咖啡專門店  ...            0
# 22               Coffee Essential (民生工寓)  ...            0
# 23                                 De 'A  ...            0
# 24                     Ecole Cafe (學校咖啡)  ...            0
# 25                      Elephant Machine  ...            0
# 26               Film Studio Café (片場咖啡)  ...            0
# 27                         Flügel Studio  ...            0
# 28   Fujin Tree 353 Cafe by Simple Kaffa  ...            0
# 29                       Good Goods Cafe  ...            0
# ..                                   ...  ...          ...
# 104                                 楽楽咖啡  ...            0
# 105                  永康階 The Green Steps  ...            0
# 106                              清玉手調原味茶  ...            0
# 107                              溫床 Nest  ...            0
# 108                滴咖啡 Drop Coffee House  ...            0
# 109                      烏鴉咖啡 Cafe Kafka  ...            0
# 110          烘培者咖啡 Roaster Family Coffee  ...            0
# 111                                   琅茶  ...            0
# 112               瑪汀妮芝咖啡 Martinez Coffee  ...            0
# 113            真書軒 The Jen Library (真書軒)  ...            0
# 114                                 米倉咖啡  ...            0
# 115                                 聞山咖啡  ...            0
# 116     自然醒咖啡公寓 Wakin' Up Cafe Apartment  ...            0
# 117                    芭蕾咖啡館 Cafe Ballet  ...            0
# 118                       葛樂蒂咖啡館 Galette  ...            0
# 119                                   覓熊  ...            0
# 120                      誰的書房 who's café  ...            0
# 121                                 貳月咖啡  ...            0
# 122                 路易 莎咖啡 Louisa Coffee  ...            0
# 123                 路易．莎咖啡 Louisa Coffee  ...            0
# 124                      路燈咖啡 Light Cafe  ...            0
# 125                         避世所 Bistro O  ...            0
# 126                   野餐咖啡 Picnic (野餐咖啡)  ...            0
# 127                              阿力的搖滾廚房  ...            0
# 128                                  雙魚坊  ...            0
# 129                 雪可屋 Shakehouse Caffe  ...            0
# 130                                 靈感咖啡  ...            0
# 131                                 青田七六  ...            0
# 132                                 青田茶館  ...            0
# 133                  魯米爺咖啡館 Café Lumiere  ...            0
#
# [134 rows x 295 columns]

# %% [markdown]
# Put the original information back in, and we have our final dataset.

# %%
df_final=df.append(df_1).merge(df_grouped,on='Name')
df_final
# Out:
#                                     Name  Likes  ...  Women's Store  Yoga Studio
# 0    Fujin Tree 353 Cafe by Simple Kaffa     68  ...              0            0
# 1               All Day Roasting Company     78  ...              0            0
# 2                Coffee Essential (民生工寓)     79  ...              0            0
# 3                      左先生咖啡 Dousun Cafe     28  ...              0            0
# 4                                   楽楽咖啡     47  ...              0            0
# 5              STARBUCKS (San Min) (星巴克)     24  ...              0            0
# 6                          Woolloomooloo     48  ...              0            0
# 7                                六丁目cafe     19  ...              0            0
# 8                           Leisure Cafe      9  ...              0            0
# 9                          朋廚烘培坊 Bonjour      7  ...              0            0
# 10                         小春日和 動物雜貨• 珈琲      6  ...              0            0
# 11         Wilbeck Café (威爾貝克手工烘咖啡（南京店）)     10  ...              0            0
# 12                               春水堂 光南店     25  ...              0            0
# 13                       小草 作 Grassphere      5  ...              0            0
# 14                         BEANS & BEATS      7  ...              0            0
# 15              Kyushu Pancake (九州鬆餅咖啡店)     15  ...              0            0
# 16                        Café Mode (木馬)      5  ...              0            1
# 17                                 De 'A      7  ...              0            0
# 18                       Starbucks (星巴克)     11  ...              0            0
# 19                     芭蕾咖啡館 Cafe Ballet      6  ...              0            0
# 20                              J12 Cafe      4  ...              0            0
# 21                                 Pausa      0  ...              0            0
# 22                            Polar Cafe      1  ...              0            0
# 23                             3,CO Cafe      2  ...              0            1
# 24              Cafe Ballet-Baby Kitchen      1  ...              0            0
# 25                          Mister Donut      0  ...              0            0
# 26                          Cafe Coabana      5  ...              0            0
# 27          Milkglider Latteartist Unity      7  ...              0            0
# 28                            cafe apron      2  ...              0            0
# 29                                 晴空巷咖啡      3  ...              0            0
# ..                                   ...    ...  ...            ...          ...
# 107                               PP99輕食      7  ...              0            0
# 108                   極簡咖啡館 Minimal Café     27  ...              0            0
# 109                滴咖啡 Drop Coffee House      8  ...              0            0
# 110                  Good Studio (好氏研究室)     15  ...              0            0
# 111                     Okey Dockey Cafe      5  ...              0            0
# 112                       Café à la Mode      8  ...              0            0
# 113                 路易 莎咖啡 Louisa Coffee      4  ...              0            0
# 114   BackStage Cafe (後台 BackStage Cafe)      1  ...              0            0
# 115                   Café Trouvé (找到咖啡)      3  ...              0            0
# 116                       Cafe Fudgetori      3  ...              0            0
# 117                                 聞山咖啡      6  ...              0            0
# 118                                小木屋鬆餅      2  ...              0            0
# 119                                  天曉得      2  ...              1            0
# 120                    小南風 Minami Zephyr      0  ...              0            0
# 121                                 米倉咖啡      2  ...              0            0
# 122                  Rose House 古典玫瑰園師大店      1  ...              0            0
# 123              Film Studio Café (片場咖啡)      2  ...              0            0
# 124                        朱利安諾 Giuliano      1  ...              0            0
# 125                 路易．莎咖啡 Louisa Coffee      1  ...              0            0
# 126                      斑比咖啡 Bambi Cafe      1  ...              0            0
# 127                      路燈咖啡 Light Cafe      9  ...              0            0
# 128                 Jamaica Cafe (牙買加倉庫)      0  ...              0            0
# 129                            コーヒー山田珈琲店      6  ...              0            0
# 130                              50嵐 師大店      2  ...              0            0
# 131                 Guang Yi Cafe (光一肆號)      1  ...              0            0
# 132      Piglet Friendly Café (彼克蕾友善咖啡館)      3  ...              0            0
# 133                             一芳 台灣水果茶      1  ...              0            0
# 134            真書軒 The Jen Library (真書軒)      5  ...              0            0
# 135                      Good Goods Cafe      1  ...              0            0
# 136                  魯米爺咖啡館 Café Lumiere      1  ...              0            0
#
# [137 rows x 300 columns]

# %% [markdown]
# Since doing regression on such a small feature set is not a good idea, we will use K-means clustering to see if we can find any patterns.

# %%
X=df_final.drop(['Name','Likes','rating','score'],axis=1)

# %%
from sklearn.cluster import KMeans
kmeans=KMeans(init='k-means++',n_clusters=5,n_init=12).fit(X)
df_final.insert(1,'Class',kmeans.labels_)
df_final.head()
# Out:
#                                   Name  Class  ...  Women's Store  Yoga Studio
# 0  Fujin Tree 353 Cafe by Simple Kaffa      3  ...              0            0
# 1             All Day Roasting Company      4  ...              0            0
# 2              Coffee Essential (民生工寓)      4  ...              0            0
# 3                    左先生咖啡 Dousun Cafe      4  ...              0            0
# 4                                 楽楽咖啡      4  ...              0            0
#
# [5 rows x 301 columns]

# %% [markdown]
# To make our dataframe easier to comprehend, we convert the table to show the 5 most common type of venues nearby.

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row#.iloc[0:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
indicators = ['st', 'nd', 'rd']
num_top_venues=5
# create columns according to number of top venues
columns = ['Name','Class','Score']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
df_final_venues_sorted = pd.DataFrame(columns=columns)
df_final_venues_sorted['Name'] = df_final['Name']
df_final_venues_sorted['Class'] = df_final['Class']
df_final_venues_sorted['Score'] = df_final['score']

for ind in np.arange(df_final.shape[0]):
    df_final_venues_sorted.iloc[ind, 3:] = return_most_common_venues(df_final.iloc[ind, 7:], num_top_venues)
df_final_venues_sorted
# Out:
#                                     Name  ...                     5th Most Common Venue
# 0    Fujin Tree 353 Cafe by Simple Kaffa  ...                            Clothing Store
# 1               All Day Roasting Company  ...                                    Bakery
# 2                Coffee Essential (民生工寓)  ...                           Bubble Tea Shop
# 3                      左先生咖啡 Dousun Cafe  ...                       Szechuan Restaurant
# 4                                   楽楽咖啡  ...                          Business Service
# 5              STARBUCKS (San Min) (星巴克)  ...                                  Building
# 6                          Woolloomooloo  ...                                 Nightclub
# 7                                六丁目cafe  ...  Residential Building (Apartment / Condo)
# 8                           Leisure Cafe  ...                                Campground
# 9                          朋廚烘培坊 Bonjour  ...                                      Park
# 10                         小春日和 動物雜貨• 珈琲  ...                               Beer Garden
# 11         Wilbeck Café (威爾貝克手工烘咖啡（南京店）)  ...                            Medical Center
# 12                               春水堂 光南店  ...                       Dumpling Restaurant
# 13                       小草 作 Grassphere  ...                       Japanese Restaurant
# 14                         BEANS & BEATS  ...                               Pop-Up Shop
# 15              Kyushu Pancake (九州鬆餅咖啡店)  ...                               Music Store
# 16                        Café Mode (木馬)  ...                                      Café
# 17                                 De 'A  ...                                   Parking
# 18                       Starbucks (星巴克)  ...                                      Café
# 19                     芭蕾咖啡館 Cafe Ballet  ...                              Noodle House
# 20                              J12 Cafe  ...                       Dumpling Restaurant
# 21                                 Pausa  ...                                  Building
# 22                            Polar Cafe  ...                                  Bus Line
# 23                             3,CO Cafe  ...                            Clothing Store
# 24              Cafe Ballet-Baby Kitchen  ...                                    Bakery
# 25                          Mister Donut  ...                                Food Stand
# 26                          Cafe Coabana  ...                                  Bus Line
# 27          Milkglider Latteartist Unity  ...                        Salon / Barbershop
# 28                            cafe apron  ...                        Chinese Restaurant
# 29                                 晴空巷咖啡  ...                                Smoke Shop
# ..                                   ...  ...                                       ...
# 107                               PP99輕食  ...                                    Bakery
# 108                   極簡咖啡館 Minimal Café  ...                            Sandwich Place
# 109                滴咖啡 Drop Coffee House  ...                        Athletics & Sports
# 110                  Good Studio (好氏研究室)  ...                               Coffee Shop
# 111                     Okey Dockey Cafe  ...                               Coffee Shop
# 112                       Café à la Mode  ...                           Laundry Service
# 113                 路易 莎咖啡 Louisa Coffee  ...                            Breakfast Spot
# 114   BackStage Cafe (後台 BackStage Cafe)  ...                          Research Station
# 115                   Café Trouvé (找到咖啡)  ...                          Basketball Court
# 116                       Cafe Fudgetori  ...                        Chinese Restaurant
# 117                                 聞山咖啡  ...                        Italian Restaurant
# 118                                小木屋鬆餅  ...                         Convenience Store
# 119                                  天曉得  ...                        Salon / Barbershop
# 120                    小南風 Minami Zephyr  ...                               Bus Station
# 121                                 米倉咖啡  ...                              Night Market
# 122                  Rose House 古典玫瑰園師大店  ...                         Convenience Store
# 123              Film Studio Café (片場咖啡)  ...             Paper / Office Supplies Store
# 124                        朱利安諾 Giuliano  ...                                    Bakery
# 125                 路易．莎咖啡 Louisa Coffee  ...                                 BBQ Joint
# 126                      斑比咖啡 Bambi Cafe  ...                              Burger Joint
# 127                      路燈咖啡 Light Cafe  ...                               Record Shop
# 128                 Jamaica Cafe (牙買加倉庫)  ...                               College Gym
# 129                            コーヒー山田珈琲店  ...                              Noodle House
# 130                              50嵐 師大店  ...                                Food Stand
# 131                 Guang Yi Cafe (光一肆號)  ...                               Bus Station
# 132      Piglet Friendly Café (彼克蕾友善咖啡館)  ...                              Dessert Shop
# 133                             一芳 台灣水果茶  ...                                Food Truck
# 134            真書軒 The Jen Library (真書軒)  ...                                Skate Park
# 135                      Good Goods Cafe  ...                        Chinese Restaurant
# 136                  魯米爺咖啡館 Café Lumiere  ...                              Dessert Shop
#
# [137 rows x 8 columns]

# %% [markdown]
# # Results

# %% [markdown]
# Let's look at each class and it's average score

# %% [markdown]
# Class 0

# %%
print(df_final_venues_sorted[df_final_venues_sorted['Class']==0]['Score'].mean())
df_final_venues_sorted[df_final_venues_sorted['Class']==0]
# Out:
# 77.53494623655912
#                                    Name  ...  5th Most Common Venue
# 76   天下佈武 日月潭紅茶 Sun Moon Lake Black Tea  ...                   Park
# 79                       petit doux 微小甜  ...               Pharmacy
# 87                               回留茶藝素食  ...             Playground
# 96                      STARBUCKS (星巴克)  ...    Japanese Restaurant
# 102                        避世所 Bistro O  ...    Japanese Restaurant
# 106                            Together  ...         Clothing Store
# 119                                 天曉得  ...     Salon / Barbershop
# 120                   小南風 Minami Zephyr  ...            Bus Station
# 121                                米倉咖啡  ...           Night Market
# 122                 Rose House 古典玫瑰園師大店  ...      Convenience Store
# 125                路易．莎咖啡 Louisa Coffee  ...              BBQ Joint
# 130                             50嵐 師大店  ...             Food Stand
#
# [12 rows x 8 columns]

# %% [markdown]
# Class 1

# %%
print(df_final_venues_sorted[df_final_venues_sorted['Class']==1]['Score'].mean())
df_final_venues_sorted[df_final_venues_sorted['Class']==1]
# Out:
# 73.38934081346423
#                   Name  Class  ...  4th Most Common Venue      5th Most Common Venue
# 41   丹堤咖啡 Dante Coffee      1  ...      Convenience Store  College Academic Building
# 42   丹堤咖啡 Dante Coffee      1  ...      Convenience Store  College Academic Building
# 43   丹堤咖啡 Dante Coffee      1  ...      Convenience Store  College Academic Building
# 104      星巴克 Starbucks      1  ...            Coffee Shop         Italian Restaurant
# 105      星巴克 Starbucks      1  ...            Coffee Shop         Italian Restaurant
#
# [5 rows x 8 columns]

# %% [markdown]
# Class 2

# %%
print(df_final_venues_sorted[df_final_venues_sorted['Class']==2]['Score'].mean())
df_final_venues_sorted[df_final_venues_sorted['Class']==2]
# Out:
# 96.38461538461539
#                                      Name  ...  5th Most Common Venue
# 56                       515 cafe & books  ...           Dessert Shop
# 61                      Yaboo Cafe (鴉埠咖啡)  ...            Coffee Shop
# 62            Libero Coffee & Bar (咖啡小自由)  ...    Leather Goods Store
# 67                        誰的書房 who's café  ...               Tea Room
# 70                    永康階 The Green Steps  ...   Taiwanese Restaurant
# 73                      Xiaomijo (小米酒咖啡館)  ...              Gift Shop
# 74                串門子茶館 Stop By Tea House  ...         Ice Cream Shop
# 80   Youmou to Ohana Coffee (羊毛與花 coffee)  ...            Coffee Shop
# 82            烘培者咖啡 Roaster Family Coffee  ...     Chinese Restaurant
# 88                           好多咖啡 Forgood  ...                   Café
# 99                        烏鴉咖啡 Cafe Kafka  ...     Salon / Barbershop
# 101                               溫床 Nest  ...   Taiwanese Restaurant
# 103                瑪汀妮芝咖啡 Martinez Coffee  ...     Salon / Barbershop
#
# [13 rows x 8 columns]

# %% [markdown]
# Class 3

# %%
print(df_final_venues_sorted[df_final_venues_sorted['Class']==3]['Score'].mean())
df_final_venues_sorted[df_final_venues_sorted['Class']==3]
# Out:
# 84.20848956693479
#                                     Name  ...          5th Most Common Venue
# 0    Fujin Tree 353 Cafe by Simple Kaffa  ...                 Clothing Store
# 6                          Woolloomooloo  ...                      Nightclub
# 9                          朋廚烘培坊 Bonjour  ...                           Park
# 14                         BEANS & BEATS  ...                    Pop-Up Shop
# 15              Kyushu Pancake (九州鬆餅咖啡店)  ...                    Music Store
# 16                        Café Mode (木馬)  ...                           Café
# 17                                 De 'A  ...                        Parking
# 21                                 Pausa  ...                       Building
# 23                             3,CO Cafe  ...                 Clothing Store
# 24              Cafe Ballet-Baby Kitchen  ...                         Bakery
# 35                         Cafe Showroom  ...             Chinese Restaurant
# 53                                  青田七六  ...                         Mosque
# 54              Wistaria Tea House (紫藤廬)  ...                    Art Gallery
# 57                    咖啡黑潮 Cafe Kuroshio  ...            Dumpling Restaurant
# 58                               2J Cafe  ...                    Pizza Place
# 59                        葛樂蒂咖啡館 Galette  ...                   Neighborhood
# 60                        AGCT Apartment  ...                    Art Gallery
# 63                             Take Five  ...            American Restaurant
# 64                     Ecole Cafe (學校咖啡)  ...                      Bookstore
# 65                                  青田茶館  ...                    Post Office
# 66                   喜鵲咖啡 Pica Pica Café  ...                 Farmers Market
# 72                     Le Chat (路上撿到一隻貓)  ...                    Art Gallery
# 75                                  靈感咖啡  ...                   Dessert Shop
# 81             Rebirth Cafe & Restaurant  ...                    Art Gallery
# 83                                   雙魚坊  ...             Italian Restaurant
# 84                      Elephant Machine  ...                       Boutique
# 85                   女巫店 the Witch House  ...             Italian Restaurant
# 86                            Cafe Odeon  ...        Health & Beauty Service
# 89                    野餐咖啡 Picnic (野餐咖啡)  ...            Sporting Goods Shop
# 93                          MySweetiePie  ...               Toy / Game Store
# 95                         Cafe Bastille  ...            Leather Goods Store
# 97                  雪可屋 Shakehouse Caffe  ...                 Clothing Store
# 98                   Halfway Cafe (半路咖啡)  ...                Bubble Tea Shop
# 100                            微光咖啡 Aura  ...              Convenience Store
# 109                滴咖啡 Drop Coffee House  ...             Athletics & Sports
# 110                  Good Studio (好氏研究室)  ...                    Coffee Shop
# 111                     Okey Dockey Cafe  ...                    Coffee Shop
# 112                       Café à la Mode  ...                Laundry Service
# 115                   Café Trouvé (找到咖啡)  ...               Basketball Court
# 117                                 聞山咖啡  ...             Italian Restaurant
# 123              Film Studio Café (片場咖啡)  ...  Paper / Office Supplies Store
# 124                        朱利安諾 Giuliano  ...                         Bakery
# 126                      斑比咖啡 Bambi Cafe  ...                   Burger Joint
# 127                      路燈咖啡 Light Cafe  ...                    Record Shop
# 129                            コーヒー山田珈琲店  ...                   Noodle House
# 131                 Guang Yi Cafe (光一肆號)  ...                    Bus Station
# 132      Piglet Friendly Café (彼克蕾友善咖啡館)  ...                   Dessert Shop
# 135                      Good Goods Cafe  ...             Chinese Restaurant
# 136                  魯米爺咖啡館 Café Lumiere  ...                   Dessert Shop
#
# [49 rows x 8 columns]

# %% [markdown]
# Class 4

# %%
print(df_final_venues_sorted[df_final_venues_sorted['Class']==4]['Score'].mean())
df_final_venues_sorted[df_final_venues_sorted['Class']==4]
# Out:
# 81.78142380422697
#                                                 Name  ...                     5th Most Common Venue
# 1                           All Day Roasting Company  ...                                    Bakery
# 2                            Coffee Essential (民生工寓)  ...                           Bubble Tea Shop
# 3                                  左先生咖啡 Dousun Cafe  ...                       Szechuan Restaurant
# 4                                               楽楽咖啡  ...                          Business Service
# 5                          STARBUCKS (San Min) (星巴克)  ...                                  Building
# 7                                            六丁目cafe  ...  Residential Building (Apartment / Condo)
# 8                                       Leisure Cafe  ...                                Campground
# 10                                     小春日和 動物雜貨• 珈琲  ...                               Beer Garden
# 11                     Wilbeck Café (威爾貝克手工烘咖啡（南京店）)  ...                            Medical Center
# 12                                           春水堂 光南店  ...                       Dumpling Restaurant
# 13                                   小草 作 Grassphere  ...                       Japanese Restaurant
# 18                                   Starbucks (星巴克)  ...                                      Café
# 19                                 芭蕾咖啡館 Cafe Ballet  ...                              Noodle House
# 20                                          J12 Cafe  ...                       Dumpling Restaurant
# 22                                        Polar Cafe  ...                                  Bus Line
# 25                                      Mister Donut  ...                                Food Stand
# 26                                      Cafe Coabana  ...                                  Bus Line
# 27                      Milkglider Latteartist Unity  ...                        Salon / Barbershop
# 28                                        cafe apron  ...                        Chinese Restaurant
# 29                                             晴空巷咖啡  ...                                Smoke Shop
# 30                                                琅茶  ...                              Noodle House
# 31                                            小樽手作咖啡  ...                        Salon / Barbershop
# 32                                 天仁茗茶 TenRen's Tea  ...                           Bubble Tea Shop
# 33                          松果院子 Restaurant Pinecone  ...                         French Restaurant
# 34             Quote Select Shop / Coffee & Sundries  ...                         Convenience Store
# 36                                        Red Circle  ...                               Pop-Up Shop
# 37                                   Afterhours Café  ...                          Dutch Restaurant
# 38                               Louisa Coffee 民生富錦店  ...                               Coffee Shop
# 39                                                覓熊  ...                       Szechuan Restaurant
# 40                                           阿力的搖滾廚房  ...                                      Park
# 44                                   敝所咖啡 Bison Cafe  ...                     Vietnamese Restaurant
# 45                                             亞熱帶餐廳  ...                      Fast Food Restaurant
# 46                                               三佰斤  ...                               Medical Lab
# 47                            伯朗咖啡館 Mr. Brown Coffee  ...                              Noodle House
# 48              Peloso Coffee Roasters 2 (沛洛瑟珈琲店．之二)  ...                        Chinese Restaurant
# 49   Mr. Brown Coffee Taipei Airport 2 (伯朗咖啡 松山機場二店)  ...                          Airport Terminal
# 50                                     A. Place Cafe  ...                                    Office
# 51                               Louisa coffee 民生圓環店  ...                           Doctor's Office
# 52                                           清玉手調原味茶  ...                             Middle School
# 55                                              貳月咖啡  ...                                      Bank
# 68                                     Flügel Studio  ...                                      Bank
# 69                                           Hi (日楞)  ...  Residential Building (Apartment / Condo)
# 71                                     MuNiau (沐肆貓廬)  ...                            Breakfast Spot
# 77                  自然醒咖啡公寓 Wakin' Up Cafe Apartment  ...                                      Café
# 78                                 小慢 Tea Experience  ...                                  Creperie
# 90                                     Café Bastille  ...                       Government Building
# 91                                      Cama 現烘咖啡專門店  ...                        Basketball Stadium
# 92                                       Pillow Café  ...                             Hot Dog Joint
# 94                   Angle Café (Angle cafe 自家烘焙咖啡館)  ...                               Candy Store
# 107                                           PP99輕食  ...                                    Bakery
# 108                               極簡咖啡館 Minimal Café  ...                            Sandwich Place
# 113                             路易 莎咖啡 Louisa Coffee  ...                            Breakfast Spot
# 114               BackStage Cafe (後台 BackStage Cafe)  ...                          Research Station
# 116                                   Cafe Fudgetori  ...                        Chinese Restaurant
# 118                                            小木屋鬆餅  ...                         Convenience Store
# 128                             Jamaica Cafe (牙買加倉庫)  ...                               College Gym
# 133                                         一芳 台灣水果茶  ...                                Food Truck
# 134                        真書軒 The Jen Library (真書軒)  ...                                Skate Park
#
# [58 rows x 8 columns]

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### 1.Distribution of clusters

# %%
import folium
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
map_clusters = folium.Map(location=[25.040667,121.556667], zoom_start=14)
x = np.arange(5)
ys = [i + x + (i*x)**2 for i in range(5)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

markers_colors = []
for lat, lon, poi, cluster in zip(df_final['latitude'], df_final['longitude'], df_final['Name'], df_final['Class']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)

map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 2.Distribution of clusters and scores

# %% [markdown]
# The color of the outer ring represents the score of the coffee shop, and the color inside represents the class label.

# %%
map_clusters = folium.Map(location=[25.040667,121.556667], zoom_start=14)
x = np.arange(5)
ys = [i + x + (i*x)**2 for i in range(5)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

x = np.arange(130)
ys = [i + x + (i*x)**2 for i in range(130)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow1 = [colors.rgb2hex(i) for i in colors_array]

markers_colors = []
for lat, lon, poi, cluster ,score in zip(df_final['latitude'], df_final['longitude'], df_final['Name'],df_final['Class'], df_final['score']):
    label = folium.Popup(str(poi) + ' Score ' + str(round(score))+' Class '+str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow1[round(score-40)],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)

map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Class 2 has a noticeably higher average score.<br>
# Let's inspect Class 2 more closely.

# %%
df_final_venues_sorted[df_final_venues_sorted['Class']==2]
# Out:
#                                      Name  ...  5th Most Common Venue
# 56                       515 cafe & books  ...           Dessert Shop
# 61                      Yaboo Cafe (鴉埠咖啡)  ...            Coffee Shop
# 62            Libero Coffee & Bar (咖啡小自由)  ...    Leather Goods Store
# 67                        誰的書房 who's café  ...               Tea Room
# 70                    永康階 The Green Steps  ...   Taiwanese Restaurant
# 73                      Xiaomijo (小米酒咖啡館)  ...              Gift Shop
# 74                串門子茶館 Stop By Tea House  ...         Ice Cream Shop
# 80   Youmou to Ohana Coffee (羊毛與花 coffee)  ...            Coffee Shop
# 82            烘培者咖啡 Roaster Family Coffee  ...     Chinese Restaurant
# 88                           好多咖啡 Forgood  ...                   Café
# 99                        烏鴉咖啡 Cafe Kafka  ...     Salon / Barbershop
# 101                               溫床 Nest  ...   Taiwanese Restaurant
# 103                瑪汀妮芝咖啡 Martinez Coffee  ...     Salon / Barbershop
#
# [13 rows x 8 columns]

# %%
df_class2=df_final[df_final['Class']==2]
map_clusters = folium.Map(location=[25.029567,121.530767], zoom_start=17)
x = np.arange(90)
ys = [i + x + (i*x)**2 for i in range(90)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

markers_colors = []
for lat, lon, poi, score in zip(df_class2['latitude'], df_class2['longitude'], df_class2['Name'], df_class2['score']):
    label = folium.Popup(str(poi) + ' Score ' + str(score), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[round(score-70)],
        fill=True,
        fill_color=rainbow[round(score-70)],
        fill_opacity=0.7).add_to(map_clusters)

map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Discussion

# %% [markdown]
# Looking at the best cluster, class 2, we found that they are generally around Taiwanese restaurants and other coffee shops.
#
# They are also all located in Da'an district.

# %% [markdown]
# Looking at the worst two clusters, class 0 and class 1, we found that they are generally around other coffee shops, bubble tea shops and convenience stores.
#
# It seems like being surrounded by lots of other shops that sell drinks is too much of a competition.

# %% [markdown]
# Also notice that while class 2 is accompanied by other coffee shops, it's not the main type of venues nearby.

# %% [markdown]
# Based on these observations, we recommend that people open their new coffee shops in Da'an District, with Taiwanese restaurants nearby, and keep a mid-range distance to other coffee shops.

# %% [markdown]
# # Conclusion

# %% [markdown]
# While there is still a lot of factors that are not considered in this project due to the limit of foursqure API, we can still make some interesting conclusions based on our observations.

# %% [markdown]
# 1. It is not recommended to have your coffee shop surrounded by all kinds of shops with drinks. It appears that competition of such an intensity is not beneficial to your business.

# %% [markdown]
# 2. It is recommended to have your coffee shop accompanied by other coffee shops, but not where coffee shops are the main type of business in that area.

# %% [markdown]
# 3. Generally, it is recommended to open your coffee shop in either Songsang District or Da'an District.

# %% [markdown]
# 4. Chained coffee shops performs fine and consistently, but not outstanding.

# %% [markdown]
# <center>This is a demonstration of using data science techniques to analyze coffee shop performance based on their location.
#
# <center>I do not in any way claim that this report represents the real world.
#
# <center>Anyone may use this report to their own interests, but I'm not responsible for any action caused by this report.
