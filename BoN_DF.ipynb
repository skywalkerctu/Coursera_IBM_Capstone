# %% [markdown]
# Import packages.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# Set url.

# %%
url="https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"

# %% [markdown]
# Get the table.

# %%
html=requests.get(url)
soup=BeautifulSoup(html.text, 'html.parser')
table=soup.find('table',{'class':'wikitable sortable'})

# %% [markdown]
# Build a dataframe from the table.

# %%
columns = [th.text.replace('\n', '') for th in table.find('tr').find_all('th')]
trs = table.find_all('tr')[1:]
rows = list()
for tr in trs:
    rows.append([td.text.replace('\n', '').replace('\xa0', '') for td in tr.find_all('td')])
df=pd.DataFrame(data=rows,columns=columns)

# %% [markdown]
# Get rid of the rows with no borough assigned and set neighbourghood to borough if not assigned.

# %%
df.drop(df[df.Borough=='Not assigned'].index,inplace=True)
df['Neighbourhood'].replace('Not assigned',df['Borough'],inplace=True)

# %% [markdown]
# Combine rows with the same postcode and sort by postcodes.

# %%
duf=df['Postcode'].duplicated(keep='first')
duf=list(duf[duf==True].index)
dul=df['Postcode'].duplicated(keep='last')
dul=list(dul[dul==True].index)
for i,j in zip(dul[::-1],duf[::-1]):
    df.loc[i,'Neighbourhood']=str(df.loc[j,'Neighbourhood'])+','+str(df.loc[i,'Neighbourhood'])
df.drop(index=duf,inplace=True)
df.sort_values('Postcode',inplace=True)
df.reset_index(drop=True,inplace=True)

# %% [markdown]
# Show the final dataframe.

# %%
df
# Out:
#     Postcode                        ...                                                              Neighbourhood
# 0        M1B                        ...                                                              Malvern,Rouge
# 1        M1C                        ...                                       Port Union,Rouge Hill,Highland Creek
# 2        M1E                        ...                                            West Hill,Morningside,Guildwood
# 3        M1G                        ...                                                                     Woburn
# 4        M1H                        ...                                                                  Cedarbrae
# 5        M1J                        ...                                                        Scarborough Village
# 6        M1K                        ...                                  Kennedy Park,Ionview,East Birchmount Park
# 7        M1L                        ...                                              Oakridge,Golden Mile,Clairlea
# 8        M1M                        ...                              Scarborough Village West,Cliffside,Cliffcrest
# 9        M1N                        ...                                                 Cliffside West,Birch Cliff
# 10       M1P                        ...                          Wexford Heights,Scarborough Town Centre,Dorset...
# 11       M1R                        ...                                                           Wexford,Maryvale
# 12       M1S                        ...                                                                  Agincourt
# 13       M1T                        ...                                      Tam O'Shanter,Sullivan,Clarks Corners
# 14       M1V                        ...                          Steeles East,Milliken,L'Amoreaux East,Agincour...
# 15       M1W                        ...                                                            L'Amoreaux West
# 16       M1X                        ...                                                                Upper Rouge
# 17       M2H                        ...                                                          Hillcrest Village
# 18       M2J                        ...                                                 Oriole,Henry Farm,Fairview
# 19       M2K                        ...                                                            Bayview Village
# 20       M2L                        ...                                                    York Mills,Silver Hills
# 21       M2M                        ...                                                     Willowdale,Newtonbrook
# 22       M2N                        ...                                                           Willowdale South
# 23       M2P                        ...                                                            York Mills West
# 24       M2R                        ...                                                            Willowdale West
# 25       M3A                        ...                                                                  Parkwoods
# 26       M3B                        ...                                                            Don Mills North
# 27       M3C                        ...                                            Don Mills South,Flemingdon Park
# 28       M3H                        ...                              Wilson Heights,Downsview North,Bathurst Manor
# 29       M3J                        ...                                             York University,Northwood Park
# ..       ...                        ...                                                                        ...
# 73       M6C                        ...                                                         Humewood-Cedarvale
# 74       M6E                        ...                                                        Caledonia-Fairbanks
# 75       M6G                        ...                                                                   Christie
# 76       M6H                        ...                                                Dufferin,Dovercourt Village
# 77       M6J                        ...                                                    Trinity,Little Portugal
# 78       M6K                        ...                                 Parkdale Village,Exhibition Place,Brockton
# 79       M6L                        ...                                           Upwood Park,North Park,Downsview
# 80       M6M                        ...                                Silverthorn,Mount Dennis,Keelesdale,Del Ray
# 81       M6N                        ...                                               Runnymede,The Junction North
# 82       M6P                        ...                                               The Junction South,High Park
# 83       M6R                        ...                                                      Roncesvalles,Parkdale
# 84       M6S                        ...                                                          Swansea,Runnymede
# 85       M7A                        ...                                                               Queen's Park
# 86       M7R                        ...                                      Canada Post Gateway Processing Centre
# 87       M7Y                        ...                          Business Reply Mail Processing Centre 969 Eastern
# 88       M8V                        ...                                 New Toronto,Mimico South,Humber Bay Shores
# 89       M8W                        ...                                                      Long Branch,Alderwood
# 90       M8X                        ...                                Old Mill North,Montgomery Road,The Kingsway
# 91       M8Y                        ...                          Sunnylea,Royal York South East,The Queensway E...
# 92       M8Z                        ...                          South of Bloor,Royal York South West,The Queen...
# 93       M9A                        ...                                                           Islington Avenue
# 94       M9B                        ...                          West Deane Park,Princess Gardens,Martin Grove,...
# 95       M9C                        ...                          Old Burnhamthorpe,Markland Wood,Eringate,Bloor...
# 96       M9L                        ...                                                              Humber Summit
# 97       M9M                        ...                                                            Humberlea,Emery
# 98       M9N                        ...                                                                     Weston
# 99       M9P                        ...                                                                  Westmount
# 100      M9R                        ...                          St. Phillips,Richview Gardens,Martin Grove Gar...
# 101      M9V                        ...                          Thistletown,South Steeles,Silverstone,Mount Ol...
# 102      M9W                        ...                                                                  Northwest
#
# [103 rows x 3 columns]

# %%
df.shape
# Out:
# (103, 3)
